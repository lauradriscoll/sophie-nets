# %%
from __future__ import absolute_import, division, print_function
import glob
import os
import pdb
import numpy as np
import numpy.random as npr
import tensorflow as tf
import sys
import matplotlib.pyplot as plt
import pdb
import getpass
from scipy import stats
from sklearn import linear_model
from numpy import linalg as LA
import numpy.random as npr
from sklearn.decomposition import PCA

ui = getpass.getuser()
if ui == 'laura':
    p = '/home/laura'
elif ui == 'lauradriscoll':
    p = '/Users/lauradriscoll/Documents'
elif ui == 'lndrisco':
    p = '/home/users/lndrisco'

net = 'stepnet'
PATH_YANGNET = os.path.join(p,'code/multitask-nets',net)

PATH_YANGNET = os.path.join(p,'code/multitask-nets',net)

sys.path.insert(0, PATH_YANGNET)
from task import generate_trials, rule_name, rule_index_map, rules_dict
from network import Model
import tools
from tools_lnd import get_T_inds, plot_N, plot_FP, name_best_ckpt, generate_Beta_epoch, make_h_combined, same_stim_trial

PATH_TO_RECURRENT_WHISPERER = p+'/code/recurrent-whisperer'#'/home/laura/code/recurrent-whisperer'#
sys.path.insert(0, PATH_TO_RECURRENT_WHISPERER)
from RecurrentWhisperer import RecurrentWhisperer

PATH_TO_FIXED_POINT_FINDER = p+'/code/fixed-point-finder' #'/home/laura/code/fixed-point-finder-experimental'#
sys.path.insert(0, PATH_TO_FIXED_POINT_FINDER)
from FixedPointFinder import FixedPointFinder
# Out:
# No display found. Using non-interactive Agg backend.
# /Users/lauradriscoll/Documents/code/recurrent-whisperer/AdaptiveLearningRate.py:18: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tornado/ioloop.py", line 1073, in start
#     handler_func(fd_obj, events)
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 456, in _handle_events
#     self._handle_recv()
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 486, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 438, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2714, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2818, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2878, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-005f989c903d>", line 9, in <module>
#     import matplotlib.pyplot as plt
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/pyplot.py", line 71, in <module>
#     from matplotlib.backends import pylab_setup
#   File "/Users/lauradriscoll/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')

# %%
def comp_eig_decomp(Ms, sort_by='real',
                                     do_compute_lefts=True):
  """Compute the eigenvalues of the matrix M. No assumptions are made on M.

  Arguments: 
    M: 3D np.array nmatrices x dim x dim matrix
    do_compute_lefts: Compute the left eigenvectors? Requires a pseudo-inverse 
      call.

  Returns: 
    list of dictionaries with eigenvalues components: sorted 
      eigenvalues, sorted right eigenvectors, and sored left eigenvectors 
      (as column vectors).
  """
  if sort_by == 'magnitude':
    sort_fun = np.abs
  elif sort_by == 'real':
    sort_fun = np.real
  else:
    assert False, "Not implemented yet."      
  
  decomps = []
  L = None  
  for M in Ms:
    evals, R = LA.eig(M)    
    indices = np.flipud(np.argsort(sort_fun(evals)))
    if do_compute_lefts:
      L = LA.pinv(R).T  # as columns      
      L = L[:, indices]
    decomps.append({'evals' : evals[indices], 'R' : R[:, indices],  'L' : L})
  
  return decomps

# %%
def plot_FP(X, D, eig_decomps, cr,lw = 3,ms = 10):
    """Plot activity is some 2D space.

        Args:
            X: Fixed points in #Fps x Neurons
            D: Neurons x 2 plotting dims
    
        """
    S = np.shape(X)[0]
    lf = .2
    rf = .2
    stable = 1
    
    for s in range(S):
        c = 'k'
        
        X_trial = np.dot(X[s,:],D.T)
        
        n_arg_unstable = np.argwhere(eig_decomps[s]['evals']>1)+1
        if len(n_arg_unstable)>0:
            for arg in range(np.max(n_arg_unstable)):
                rdots = np.dot(np.real(eig_decomps[s]['R'][:, arg]).T,D.T)
                ldots = np.dot(np.real(eig_decomps[s]['L'][:, arg]).T,D.T)
                overlap = np.dot(rdots,ldots.T)
                r = np.concatenate((X_trial - rf*overlap*rdots, X_trial + rf*overlap*rdots),0)
                plt.plot(r[0:4:2],r[1:4:2],'k',alpha = .9,linewidth = lw)
        
        n_arg_super = np.argwhere(eig_decomps[s]['evals']<.3)
        if len(n_arg_super)>0:
            for arg in range(np.min(n_arg_super),len(eig_decomps[s]['evals'])):
                rdots = np.dot(np.real(eig_decomps[s]['R'][:, arg]).T,D.T)
                ldots = np.dot(np.real(eig_decomps[s]['L'][:, arg]).T,D.T)
                overlap = np.dot(rdots,ldots.T)
                r = np.concatenate((X_trial - rf*overlap*rdots, X_trial + rf*overlap*rdots),0)
                plt.plot(r[0:4:2],r[1:4:2],'b',alpha = .9,linewidth = lw)
            
        plt.plot(X_trial[0],X_trial[1],'o',c = cr, markersize = ms)
        if len(n_arg_unstable)>0:
            plt.plot(X_trial[0],X_trial[1],'.',c = 'k', markersize = ms)
        else:
            plt.plot(X_trial[0],X_trial[1],'.',c = 'k', markersize = ms)

def make_axes(model_dir_all,ckpt_n_dir,rule_master,epoch):

    model = Model(model_dir_all)
    with tf.Session() as sess:

        model.saver.restore(sess,ckpt_n_dir)
        # get all connection weights and biases as tensorflow variables
        var_list = model.var_list
        # evaluate the parameters after training
        params = [sess.run(var) for var in var_list]
        # get hparams
        hparams = model.hp
        trial_master = generate_trials(rule_master, hparams, mode = 'test', batch_size = 400, noise_on=False, delay_fac =1)
        feed_dict = tools.gen_feed_dict(model, trial_master, hparams)
        h_tf = sess.run(model.h, feed_dict=feed_dict) #(n_time, n_trials, n_neuron)

    Beta_epoch = generate_Beta_epoch(h_tf,trial_master)
    X_pca = Beta_epoch[epoch]    
    D = np.concatenate((np.expand_dims(X_pca[:,0],axis=1),np.expand_dims(X_pca[:,1],axis=1)),axis = 1)
    return D

# %%
def plot_fp_struct_multicolor(m,ckpt_n_dir,tasks,trial_set,r,D,fp_epoch,axes_epoch,do_plot_FP,
                              t_num = 0,qlim = .000001,color_label = 'stim1',lw = 5,ms = 3):
    cmap=plt.get_cmap('rainbow')
    plt.rcParams.update({'font.size': 18})

    ## plot w test set of trials
    model = Model(m)
    with tf.Session() as sess:
        model.saver.restore(sess,ckpt_n_dir)
        hparams = model.hp

        for rule_ind in tasks:
            rule = rules_dict['all'][rule_ind]
            trial_master = generate_trials('delaygo', hparams, mode='test', batch_size = 100, noise_on=True, delay_fac =1)
            trial = same_stim_trial(trial_master, tasks[0])
            feed_dict = tools.gen_feed_dict(model, trial, hparams)
            h_tf, _ = sess.run([model.h, model.y_hat], feed_dict=feed_dict) #(n_time, n_condition, n_neuron)

            T_inds = get_T_inds(trial,fp_epoch) # grab epoch time indexing

            fldr = os.path.join(m,'golub_fixed_pts',rule,fp_epoch+'*')
            f_list = [f for f in glob.glob(fldr)]

            T,S,N = np.shape(h_tf)
            
            stim1_locs = np.min(trial.stim_locs[:,[0,2]],axis=1)
            stim2_locs = np.min(trial.stim_locs[:,[1,3]],axis=1)
            y_loc = trial.y_loc[-1,:]
            
            if color_label == 'stim1' or color_label == 'delay1':
                c_inds = stim1_locs
            elif color_label == 'stim2' or color_label == 'delay2':
                c_inds = stim2_locs
            else:
                c_inds = y_loc
            
            if do_plot_FP==0:
                for s in range(0,S,int(S/20)):
                    c = cmap(c_inds[s]/(2*np.pi))
                    X_trial = np.dot(h_tf[T_inds,s,:],D)
                    plt.plot(X_trial[0,0],X_trial[0,1],'^',c = c, linewidth = lw)
                    plt.plot(X_trial[:,0],X_trial[:,1],'-',c = c, linewidth = lw)
                    
                    if s==0:
                        plt.plot(X_trial[-1,0],X_trial[-1,1],'o',c = c, linewidth = .3,label = rule)
                    else:
                        plt.plot(X_trial[-1,0],X_trial[-1,1],'o',c = c, linewidth = .3)
                    
            elif do_plot_FP==1:
                
                c = 'gray'
                for s in range(0,S,int(S/20)):
                    X_trial = np.dot(h_tf[T_inds,s,:],D)
                    plt.plot(X_trial[0,0],X_trial[0,1],'^',c = c, linewidth = lw)
                    plt.plot(X_trial[:,0],X_trial[:,1],'-',c = c, linewidth = lw)
                    plt.plot(X_trial[-1,0],X_trial[-1,1],'o',c = c, linewidth = lw)
                        
                s = t_num
                filename = os.path.join(m,'golub_fixed_pts',rule,fp_epoch+'_'+str(t_num)+'.npz')

                if os.path.exists(filename):
                    print(filename)
                else:
                    filename = os.path.join(m,'golub_fixed_pts',rule,fp_epoch+'_'+str(0)+'.npz')
                    
                fp_struct = np.load(filename)
                c = cmap(c_inds[s]/(2*np.pi))

                X_trial = np.dot(h_tf[T_inds,s,:],D)
                plt.plot(X_trial[0,0],X_trial[0,1],'^',c = c, linewidth = lw)
                plt.plot(X_trial[:,0],X_trial[:,1],'-',c = c, linewidth = lw)
                plt.plot(X_trial[-1,0],X_trial[-1,1],'o',c = c, linewidth = lw,label = rule)

                fp_logic = fp_struct['qstar']< qlim
                eig_decomps = comp_eig_decomp(fp_struct['J_xstar'][fp_logic,:,:])
                sorted_fps = fp_struct['xstar'][fp_logic,:]
                plot_FP(sorted_fps, D.T, eig_decomps, c, lw = 1, ms = ms)
                
            elif do_plot_FP==2:
                
                for s in range(len(f_list)):
                    filename = f_list[s]

                    if os.path.exists(filename):
                        print(filename)
                        fp_struct = np.load(filename)
                        c = cmap((fp_struct['trial_num']/80))
                        if fp_struct['trial_num']%4==0:

                            X_trial = np.dot(h_tf[T_inds,fp_struct['trial_num'],:],D)
                            plt.plot(X_trial[0,0],X_trial[0,1],'^',c = c, linewidth = lw)
                            plt.plot(X_trial[:,0],X_trial[:,1],'-',c = c, linewidth = lw)
                            plt.plot(X_trial[-1,0],X_trial[-1,1],'o',c = c, linewidth = lw)

                            fp_logic = fp_struct['qstar']< qlim
                            eig_decomps = comp_eig_decomp(fp_struct['J_xstar'][fp_logic,:,:])
                            sorted_fps = fp_struct['xstar'][fp_logic,:]
                            plot_FP(sorted_fps, D.T, eig_decomps, c,lw = 1)

            plt.xlabel(r + ' Beta_' + axes_epoch + ' cos@')
            plt.ylabel(r + ' Beta_' + axes_epoch + ' sin@') 
            plt.title(rule + ' ' + fp_epoch+' activity')

# %%
def plot_fp_struct_eigenspec(rule,fp_epoch,t_num=0,do_nfp=1):
    
    T,S,N = np.shape(h_tf)
    filename = os.path.join(model_dir_all,'golub_fixed_pts',rule,fp_epoch+'_'+str(t_num)+'.npz')

    if os.path.exists(filename):
        fp_struct = np.load(filename)
        fp_logic = fp_struct['qstar']<.0000001
        eig_decomps = comp_eig_decomp(fp_struct['J_xstar'][fp_logic,:,:])
        
        plt.subplot()
        
        if do_nfp == 0:
            plt.plot(eig_decomps[nfp]['evals'].real,eig_decomps[nfp]['evals'].imag,'.k')
            plt.title('max eigenval : ' +str(np.max(eig_decomps[nfp]['evals'].real)))
        else:
            for nfp in range(len(eig_decomps)):
                plt.plot(eig_decomps[nfp]['evals'].real,eig_decomps[nfp]['evals'].imag,alpha = .1)
                plt.title('max eigenval : ' +str(np.max(eig_decomps[nfp]['evals'].real)),alpha = .1)

# %%
net = 'stepnet'
tasks = [18]
rule = 'delaygo'#rules_dict['all'][tasks[0]]
fp_epoch = 'stim1'
model_n = 1
dir_specific_all = 'crystals/softplus/l2h00001'#'crystals/softplus/l2w0001'#'crystals/softplus/l2h00001'#'crystals/softplus/l2h00001'#'stepnet/crystals/softplus/'#grad_norm_both/'#'lowD/combos'#'stepnet/lowD/tanh'#'lowD/grad_norm_l2001' #' #'lowD/armnet_noreg'#lowD/combos' ##grad_norm_l2h000001' /Documents/data/rnn/multitask/varGo/lowD/most/
model_dir_all = os.path.join(p,'data/rnn/multitask/',dir_specific_all,str(model_n))
ckpt_n = name_best_ckpt(model_dir_all,rule)
ckpt_n_dir = os.path.join(model_dir_all,'ckpts/model.ckpt-' + str(int(ckpt_n)))

task_list = ['fdgo', 'reactgo', 'delaygo', 'fdanti', 'reactanti', 'delayanti',
              'delaydm1', 'delaydm2', 'contextdelaydm1', 'contextdelaydm2', 'multidelaydm',
              'dmsgo', 'dmsnogo', 'dmcgo', 'dmcnogo']

## plot w test set of trials
model = Model(model_dir_all)
with tf.Session() as sess:
    model.saver.restore(sess,ckpt_n_dir)
    hparams = model.hp
    trial_master = generate_trials(rule, hparams, mode='test', batch_size = 100, noise_on=True, delay_fac =1)
    trial = same_stim_trial(trial_master, tasks[0])
    feed_dict = tools.gen_feed_dict(model, trial, hparams)
    h_tf, _ = sess.run([model.h, model.y_hat], feed_dict=feed_dict) #(n_time, n_condition, n_neuron)

T,S,N = np.shape(h_tf)
trial_set = range(0,S,10)
epoch_set = trial.epochs.keys()
print(trial.epochs.keys())
# Out:
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# ['delay1', 'stim1', 'go1', 'fix1']

# %%
epoch_order = [3,1,0,2]
axes_epoch = 'stim1'

fig = plt.figure(figsize=(len(epoch_set)*10,10),tight_layout=True,facecolor='white')
plt.rcParams.update({'font.size': 20})

for fp_epoch_ind in range(len(epoch_set)):
    fp_epoch = epoch_set[epoch_order[fp_epoch_ind]]
    D = make_axes(model_dir_all,ckpt_n_dir,rule,axes_epoch)
    ax = plt.subplot(1,len(epoch_set),fp_epoch_ind+1)
    plot_fp_struct_multicolor(model_dir_all,ckpt_n_dir,tasks,trial_set,rule,-D,fp_epoch,axes_epoch,do_plot_FP=0,lw = 5)
    
    plt.ylim((-.3,.3))
    plt.xlim((-.3,.3))
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    
figpath = os.path.join(model_dir_all,'tf_fixed_pt_figs',rule)
figname = rule+'_'+axes_epoch+'_axes_Activity_all_trials.pdf'
if not os.path.exists(figpath):
    os.makedirs(figpath)
plt.savefig(os.path.join(figpath,figname))
plt.show()
# Out:
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# either
# either
# either
# either
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# either
# either
# either
# either
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# either
# either
# either
# either
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# either
# either
# either
# either
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000

# %%
epoch_order = [3,1,0,2]
axes_epoch = 'stim1'
for t_num in range(0,80,16):

    fig = plt.figure(figsize=(len(epoch_set)*10,10),tight_layout=True,facecolor='white')
    plt.rcParams.update({'font.size': 20})
    for fp_epoch_ind in range(len(epoch_set)):
        fp_epoch = epoch_set[epoch_order[fp_epoch_ind]]
#         D = make_axes(model_dir_all,ckpt_n_dir,rule,axes_epoch)
        ax = plt.subplot(1,len(epoch_set),fp_epoch_ind+1)
        plot_fp_struct_multicolor(model_dir_all,ckpt_n_dir,tasks,trial_set,rule,-D,
                                  fp_epoch,axes_epoch,t_num = t_num,do_plot_FP=1,qlim = .00000000001)

        plt.ylim((-.3,.3))
        plt.xlim((-.3,.3))
        ax.spines['right'].set_visible(False)
        ax.spines['top'].set_visible(False)

    figpath = os.path.join(model_dir_all,'tf_fixed_pt_figs',rule)
    if not os.path.exists(figpath):
        os.makedirs(figpath)

    figname = rule+'_'+axes_epoch+'_axes_Fp_one_trial_'+str(t_num)+'.pdf'
    plt.savefig(os.path.join(figpath,figname))
    figname = rule+'_'+axes_epoch+'_axes_Fp_one_trial_'+str(t_num)+'.png'
    plt.savefig(os.path.join(figpath,figname))
    plt.show()
# Out:
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/fix1_0.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_0.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/delay1_0.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/go1_0.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_16.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/go1_16.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_32.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/go1_32.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_48.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/go1_48.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_64.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/go1_64.npz

# %%
epoch_order = [0,]
epoch_set = ['stim1',]

fig = plt.figure(figsize=(10,10),tight_layout=True,facecolor='white')
plt.rcParams.update({'font.size': 20})
fp_epoch = 'stim1'
fig = plt.figure(figsize=(10,10),tight_layout=True,facecolor='white')
ax1 = plt.subplot(1,1,1)
plot_fp_struct_multicolor(model_dir_all,ckpt_n_dir,tasks,trial_set,rule,-D,fp_epoch,axes_epoch,do_plot_FP=0,lw = 5)

plt.ylim((-.3,.3))
plt.xlim((-.3,.3))
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)

figpath = os.path.join(model_dir_all,'tf_fixed_pt_figs',rule)
if not os.path.exists(figpath):
    os.makedirs(figpath)

figname = rule+'_'+axes_epoch+'_axes_Activity_all_trials.pdf'
plt.savefig(os.path.join(figpath,figname))
figname = rule+'_'+axes_epoch+'_axes_Activity_all_trials.png'
plt.savefig(os.path.join(figpath,figname))
plt.show()
# Out:
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000

# %%
epoch_order = [0,]
epoch_set = ['stim1',]
for t_num in range(0,80,16):

    fig = plt.figure(figsize=(10,10),tight_layout=True,facecolor='white')
    plt.rcParams.update({'font.size': 20})
    fp_epoch = 'stim1'
#     D = make_axes(model_dir_all,ckpt_n_dir,rule,axes_epoch)
    fig = plt.figure(figsize=(10,10),tight_layout=True,facecolor='white')
    ax1 = plt.subplot(1,1,1)
    plot_fp_struct_multicolor(model_dir_all,ckpt_n_dir,tasks,trial_set,rule,-D,
                              fp_epoch,axes_epoch,t_num = t_num,do_plot_FP=1,qlim = .00000000001,lw = 3,ms = 3)

    plt.ylim((-.3,.3))
    plt.xlim((-.3,.3))
    ax1.spines['right'].set_visible(False)
    ax1.spines['top'].set_visible(False)

    figpath = os.path.join(model_dir_all,'tf_fixed_pt_figs',rule)
    if not os.path.exists(figpath):
        os.makedirs(figpath)

    figname = rule+'_'+axes_epoch+'_axes_Fp_one_trial_'+str(t_num)+'.pdf'
    plt.savefig(os.path.join(figpath,figname))
    figname = rule+'_'+axes_epoch+'_axes_Fp_one_trial_'+str(t_num)+'.png'
    plt.savefig(os.path.join(figpath,figname))
    plt.show()
# Out:
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_0.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_16.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_32.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_48.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_64.npz

# %%
epoch_order = [0,]
epoch_set = ['stim1',]
sorted_fps,eig_decomps,c = 0,0,0
for t_num in range(1):

    fig = plt.figure(figsize=(10,10),tight_layout=True,facecolor='white')
    plt.rcParams.update({'font.size': 20})
    fp_epoch = 'stim1'
    D = make_axes(model_dir_all,ckpt_n_dir,rule,axes_epoch)
    fig = plt.figure(figsize=(10,10),tight_layout=True,facecolor='white')
    ax1 = plt.subplot(1,1,1)
    plot_fp_struct_multicolor(model_dir_all,ckpt_n_dir,tasks,trial_set,rule,D,
                              fp_epoch,axes_epoch,t_num = t_num,do_plot_FP=0,qlim = .000001,lw = 3,ms = 3)

    plt.ylim((-.3,.3))
    plt.xlim((-.3,.3))
    ax1.spines['right'].set_visible(False)
    ax1.spines['top'].set_visible(False)

    figpath = os.path.join(model_dir_all,'tf_fixed_pt_figs',rule)
    if not os.path.exists(figpath):
        os.makedirs(figpath)

    figname = rule+'_'+axes_epoch+'_axes_Activity_all_trials_'+str(t_num)+'.pdf'
    plt.savefig(os.path.join(figpath,figname))
    figname = rule+'_'+axes_epoch+'_axes_Activity_all_trials_'+str(t_num)+'.png'
    plt.savefig(os.path.join(figpath,figname))
    plt.show()
# Out:
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# either
# either
# either
# either
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000

# %%
epoch_order = [0,]
epoch_set = ['stim1',]
sorted_fps,eig_decomps,c = 0,0,0

fig = plt.figure(figsize=(10,10),tight_layout=True,facecolor='white')
plt.rcParams.update({'font.size': 20})
fp_epoch = 'stim1'
# D = make_axes(model_dir_all,ckpt_n_dir,rule,axes_epoch)
fig = plt.figure(figsize=(10,10),tight_layout=True,facecolor='white')
ax1 = plt.subplot(1,1,1)
plot_fp_struct_multicolor(model_dir_all,ckpt_n_dir,tasks,trial_set,rule,-D,
                          fp_epoch,axes_epoch,t_num = t_num,do_plot_FP=2,qlim = .00000009,lw = 3,ms = 3)

plt.ylim((-.3,.3))
plt.xlim((-.3,.3))
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)

figpath = os.path.join(model_dir_all,'tf_fixed_pt_figs',rule)
if not os.path.exists(figpath):
    os.makedirs(figpath)

figname = rule+'_'+axes_epoch+'_axes_ActivityFP_all_trials.pdf'
plt.savefig(os.path.join(figpath,figname))
figname = rule+'_'+axes_epoch+'_axes_ActivityFP_all_trials.png'
plt.savefig(os.path.join(figpath,figname))
plt.show()
# Out:
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1364000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_58.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_70.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_64.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_72.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_66.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_62.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_76.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_48.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_60.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_74.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_12.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_38.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_10.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_8.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_28.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_14.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_16.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_32.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_26.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_6.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_30.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_4.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_24.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_18.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_20.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_0.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_34.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_2.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_22.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_36.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_44.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_50.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_78.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_46.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_52.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_56.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_42.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_54.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_40.npz
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_68.npz

# %%
from tools_lnd import get_model_params
w_in, b_in, w_out, b_out = get_model_params(model_dir_all,ckpt_n_dir)

axes_epoch = 'delay1'
D_delay1 = make_axes(model_dir_all,ckpt_n_dir,'dmcgo', axes_epoch)
D = np.concatenate((D_delay1[:,:1],w_out[:,1:2]),axis = 1)

fig = plt.figure(figsize=(len(epoch_set)*5,5),tight_layout=True,facecolor='white')
t_num = 0

for fp_epoch_ind in range(len(epoch_set)):
    fp_epoch = epoch_set[epoch_order[fp_epoch_ind]]
    plt.subplot(1,len(epoch_set),fp_epoch_ind+1)
    plot_fp_struct_multicolor(model_dir_all,ckpt_n_dir,tasks,trial_set,rule,D,fp_epoch,axes_epoch,do_plot_FP=1,qlim = .00001,t_num = t_num,color_label = 'yloc')
    plt.ylabel('cosine output')
    plt.xlabel('tdr on cosine '+ axes_epoch)
    plt.ylim((-1.25,1.25))
    plt.xlim((-.3,.3))

figpath = os.path.join(model_dir_all,'tf_fixed_pt_figs',rule)
figname = rule+'_'+'output_axes'+'_axes_Fp_one_trial_'+str(t_num)+'.pdf'
if not os.path.exists(figpath):
    os.makedirs(figpath)
plt.savefig(os.path.join(figpath,figname))
plt.show()
# Out:
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1338000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1338000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1338000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/fix1_0.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1338000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_0.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1338000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/delay1_0.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1338000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/go1_0.npz

# %%
from tools_lnd import get_model_params
w_in, b_in, w_out, b_out = get_model_params(model_dir_all,ckpt_n_dir)

axes_epoch = 'delay1'
D_delay1 = make_axes(model_dir_all,ckpt_n_dir,'dmcgo', axes_epoch)
D = w_out[:,1:]

fig = plt.figure(figsize=(len(epoch_set)*5,5),tight_layout=True,facecolor='white')
t_num = 0

for fp_epoch_ind in range(len(epoch_set)):
    fp_epoch = epoch_set[epoch_order[fp_epoch_ind]]
    plt.subplot(1,len(epoch_set),fp_epoch_ind+1)
    plot_fp_struct_multicolor(model_dir_all,ckpt_n_dir,tasks,trial_set,rule,D,fp_epoch,axes_epoch,do_plot_FP=1,qlim = .00001,t_num = t_num,color_label = 'yloc')
    plt.xlabel('cosine output')
    plt.ylabel('sine output')
    plt.ylim((-1.25,1.25))
    plt.xlim((-1.25,1.25))

figpath = os.path.join(model_dir_all,'tf_fixed_pt_figs',rule)
figname = rule+'_'+'output'+'_axes_Fp_one_trial_'+str(t_num)+'.pdf'
if not os.path.exists(figpath):
    os.makedirs(figpath)
plt.savefig(os.path.join(figpath,figname))
plt.show()
# Out:
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1338000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1338000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1338000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/fix1_0.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1338000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/stim1_0.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1338000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/delay1_0.npz
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1338000
# /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/golub_fixed_pts/dmcgo/go1_0.npz

# %%
fig = plt.figure(figsize=(len(epoch_set)*5,5),tight_layout=True,facecolor='white')
t_num = 0

for fp_epoch_ind in range(len(epoch_set)):
    fp_epoch = epoch_set[epoch_order[fp_epoch_ind]]
    plt.subplot(1,len(epoch_set),fp_epoch_ind+1)
    plot_fp_struct_multicolor(model_dir_all,ckpt_n_dir,tasks,trial_set,rule,D,fp_epoch,axes_epoch,do_plot_FP=0,qlim = .0000001,t_num = t_num,color_label = 'yloc')
    plt.ylim((-1.25,1.25))
    plt.xlim((-.25,.25))

figpath = os.path.join(model_dir_all,'tf_fixed_pt_figs',rule)
figname = rule+'_'+'output_axes'+'_axes_Activity_all_trials.pdf'
if not os.path.exists(figpath):
    os.makedirs(figpath)
plt.savefig(os.path.join(figpath,figname))
plt.show()
# Out:
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1338000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1338000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1338000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1338000

# %%
net = 'stepnet'
tasks = [18]
rule = rules_dict['all'][tasks[0]]
fp_epoch = 'stim1'
model_n = 1
dir_specific_all = 'crystals/softplus/l2h00001'#'crystals/softplus/l2h00001'#'stepnet/crystals/softplus/'#grad_norm_both/'#'lowD/combos'#'stepnet/lowD/tanh'#'lowD/grad_norm_l2001' #' #'lowD/armnet_noreg'#lowD/combos' ##grad_norm_l2h000001' /Documents/data/rnn/multitask/varGo/lowD/most/
model_dir_all = os.path.join(p,'data/rnn/multitask/',dir_specific_all,str(model_n))
ckpt_n = name_best_ckpt(model_dir_all,rule)
ckpt_n_dir = os.path.join(model_dir_all,'ckpts/model.ckpt-' + str(int(ckpt_n)))

task_list = ['fdgo', 'reactgo', 'delaygo', 'fdanti', 'reactanti', 'delayanti',
              'delaydm1', 'delaydm2', 'contextdelaydm1', 'contextdelaydm2', 'multidelaydm',
              'dmsgo', 'dmsnogo', 'dmcgo', 'dmcnogo']

## plot w test set of trials
model = Model(model_dir_all)
with tf.Session() as sess:
    model.saver.restore(sess,ckpt_n_dir)
    hparams = model.hp
    trial = generate_trials(rule, hparams, mode='test', batch_size = 100, noise_on=True, delay_fac =1)
    feed_dict = tools.gen_feed_dict(model, trial, hparams)
    h_tf, _ = sess.run([model.h, model.y_hat], feed_dict=feed_dict) #(n_time, n_condition, n_neuron)

T,S,N = np.shape(h_tf)
trial_set = range(0,S,10)
epoch_set = trial.epochs.keys()
print(trial.epochs.keys())
# Out:
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1338000
# ['delay1', 'stim1', 'go1', 'fix1']

# %%
from tools_lnd import get_model_params
w_in, b_in, w_out, b_out = get_model_params(model_dir_all,ckpt_n_dir)

D_delay1 = make_axes(model_dir_all,ckpt_n_dir,'dmcgo','delay1')
D = np.concatenate((D_delay1[:,:1],w_out[:,1:2]),axis = 1)
# Out:
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1338000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1338000

# %%
axes_epoch = 'delay1'
D = make_axes(model_dir_all,ckpt_n_dir,'dmcgo',axes_epoch)
D_out = np.concatenate((D[:,0:1],w_out[:,1:2]),axis = 1)
D_use = D_out
qlim = .000001
nc = 2

cmap=plt.get_cmap('rainbow')
plt.rcParams.update({'font.size': 18})
fp_epoch = 'go1'

rule = rules_dict['all'][18]
fldr = os.path.join(model_dir_all,'golub_fixed_pts',rule,'random_trials',fp_epoch+'*')
f_list = [f for f in glob.glob(fldr)]

for s in range(0,33,33):
    fig = plt.figure(figsize=(5*nc,5),tight_layout=True,facecolor='white')
#     filename = os.path.join(model_dir_all,'golub_fixed_pts',rule,'random_trials',fp_epoch+'_'+str(s)+'.npz')
    filename = os.path.join(model_dir_all,'golub_fixed_pts',rule,fp_epoch+'_'+str(s)+'.npz')
    fp_struct = np.load(filename)

    S,T,N = np.shape(fp_struct['state_traj'])
    h_tf = np.transpose(fp_struct['state_traj'],(1,0,2))
    T_inds = range(100,T)
    
#     plt.subplot(1,nc,1)
#     c = 'gray'
#     for gray_trial in range(S):
#         X_trial = np.dot(h_tf[T_inds,gray_trial,:],D)
#         plt.plot(X_trial[0,0],X_trial[0,1],'^',c = c, linewidth = 1)
#         plt.plot(X_trial[:,0],X_trial[:,1],'-',c = c, linewidth = 1)
#         plt.plot(X_trial[-1,0],X_trial[-1,1],'o',c = c, linewidth = .3)

#     theta = (2*np.pi+np.arctan2(fp_struct['inputs'][0,3],fp_struct['inputs'][0,4]))%(2*np.pi)
#     c = cmap(theta/(2*np.pi))

#     X_trial = np.dot(h_tf[T_inds,s,:],D)
#     plt.plot(X_trial[0,0],X_trial[0,1],'^',c = c, linewidth = 2)
#     plt.plot(X_trial[:,0],X_trial[:,1],'-',c = c, linewidth = 2)
#     plt.plot(X_trial[-1,0],X_trial[-1,1],'o',c = c, linewidth = .5,label = rule)

#     fp_logic = fp_struct['qstar']< qlim
#     eig_decomps = comp_eig_decomp(fp_struct['J_xstar'][fp_logic,:,:])
#     sorted_fps = fp_struct['xstar'][fp_logic,:]
#     plot_FP(sorted_fps, D.T, eig_decomps, c)
#     plt.ylim((-.15,.15))
#     plt.xlim((-.3,.3))
#     plt.xlabel('tdr on cosine '+ axes_epoch)
#     plt.ylabel('tdr on sine '+ axes_epoch)
    
    plt.subplot(1,nc,1)
    c = 'gray'
    for gray_trial in range(S):
        X_trial = np.dot(h_tf[T_inds,gray_trial,:],D_use)
        plt.plot(X_trial[0,0],X_trial[0,1],'^',c = c, linewidth = 1)
        plt.plot(X_trial[:,0],X_trial[:,1],'-',c = c, linewidth = 1)
        plt.plot(X_trial[-1,0],X_trial[-1,1],'o',c = c, linewidth = .3)

    
    theta = (2*np.pi+np.arctan2(fp_struct['inputs'][0,3],fp_struct['inputs'][0,4]))%(2*np.pi)
    c = cmap(theta/(2*np.pi))

    X_trial = np.dot(h_tf[T_inds,s,:],D_use)
    plt.plot(X_trial[0,0],X_trial[0,1],'^',c = c, linewidth = 2)
    plt.plot(X_trial[:,0],X_trial[:,1],'-',c = c, linewidth = 2)
    plt.plot(X_trial[-1,0],X_trial[-1,1],'o',c = c, linewidth = .5,label = rule)

    fp_logic = fp_struct['qstar']< qlim
    eig_decomps = comp_eig_decomp(fp_struct['J_xstar'][fp_logic,:,:])
    sorted_fps = fp_struct['xstar'][fp_logic,:]
    plot_FP(sorted_fps, D_use.T, eig_decomps, c)
    plt.ylim((-1.2,1.2))
    plt.xlim((-.3,.3))
    plt.xlabel('tdr on cosine '+ axes_epoch)
    plt.ylabel('cosine output')
    
    plt.subplot(1,nc,2)
    X_trial = np.dot(h_tf[T_inds,s,:],w_out[:,1:3])
    plt.plot(X_trial[0,0],X_trial[0,1],'^',c = c, linewidth = 2)
    plt.plot(X_trial[:,0],X_trial[:,1],'-',c = c, linewidth = 2)
    plt.plot(X_trial[-1,0],X_trial[-1,1],'o',c = c, linewidth = .5,label = rule)
    plt.ylim((-1.2,1.2))
    plt.xlim((-1.2,1.2))
    plt.ylabel('sine output')
    plt.xlabel('cosine output')
    
    figpath = os.path.join(model_dir_all,'tf_fixed_pt_figs',rule)
    figname = rule+'_'+'output'+'_axes_FP_random'+str(s)+'.pdf'
    if not os.path.exists(figpath):
        os.makedirs(figpath)
    plt.savefig(os.path.join(figpath,figname))
    plt.show()
# Out:
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/1/ckpts/model.ckpt-1338000

# %%
epoch_order = [3,1,0,2]
axes_epoch = 'output'

fig = plt.figure(figsize=(len(epoch_set)*5,5),tight_layout=True,facecolor='white')

for fp_epoch_ind in range(len(epoch_set)):
    fp_epoch = epoch_set[epoch_order[fp_epoch_ind]]
    plt.subplot(1,len(epoch_set),fp_epoch_ind+1)
    plot_fp_struct_multicolor(model_dir_all,ckpt_n_dir,tasks,trial_set,rule,D_use,fp_epoch,axes_epoch,do_plot_FP=0)
    plt.ylim((-1.2,1.2))
    plt.xlim((-.3,.3))
    
figpath = os.path.join(model_dir_all,'tf_fixed_pt_figs',rule)
figname = rule+'_'+axes_epoch+'_axes_Activity_all_trials.pdf'
if not os.path.exists(figpath):
    os.makedirs(figpath)
plt.savefig(os.path.join(figpath,figname))
plt.show()
# Out:
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/0/ckpts/model.ckpt-1208000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/0/ckpts/model.ckpt-1208000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/0/ckpts/model.ckpt-1208000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/0/ckpts/model.ckpt-1208000

# %%
D = make_axes(model_dir_all,ckpt_n_dir,'dmcgo','stim1')
D_out = np.concatenate((D[:,0:1],w_out[:,1:2]),axis = 1)
D_use = D_out
qlim = .000001

cmap=plt.get_cmap('rainbow')
plt.rcParams.update({'font.size': 18})
fp_epoch = 'go1'

rule = rules_dict['all'][18]
fldr = os.path.join(model_dir_all,'golub_fixed_pts',rule,'random_trials',fp_epoch+'*')
f_list = [f for f in glob.glob(fldr)]

for s in range(0,33,8):
    fig = plt.figure(figsize=(10,5),tight_layout=True,facecolor='white')
    filename = os.path.join(model_dir_all,'golub_fixed_pts',rule,'random_trials',fp_epoch+'_'+str(s)+'.npz')
    fp_struct = np.load(filename)

    S,T,N = np.shape(fp_struct['state_traj'])
    h_tf = np.transpose(fp_struct['state_traj'],(1,0,2))
    T_inds = range(100,T)
    
    c = 'gray'
    plt.subplot(1,2,1)
    for gray_trial in range(S):
        X_trial = np.dot(h_tf[T_inds,gray_trial,:],D_use)
        plt.plot(X_trial[0,0],X_trial[0,1],'^',c = c, linewidth = 1)
        plt.plot(X_trial[:,0],X_trial[:,1],'-',c = c, linewidth = 1)
        plt.plot(X_trial[-1,0],X_trial[-1,1],'o',c = c, linewidth = .3)

    
    theta = np.arctan2(fp_struct['inputs'][0,3],fp_struct['inputs'][0,4])+np.pi
    c = cmap(theta/(2*np.pi))
    plt.ylim((-1.2,1.2))
    plt.xlim((-.3,.3))
    
    plt.subplot(1,2,2)
    X_trial = np.dot(h_tf[T_inds,s,:],w_out[:,1:3])
    plt.plot(X_trial[0,0],X_trial[0,1],'^',c = c, linewidth = 2)
    plt.plot(X_trial[:,0],X_trial[:,1],'-',c = c, linewidth = 2)
    plt.plot(X_trial[-1,0],X_trial[-1,1],'o',c = c, linewidth = .5,label = rule)
    plt.ylim((-1.2,1.2))
    plt.xlim((-1.2,1.2))
    plt.show()
# Out:
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/0/ckpts/model.ckpt-1208000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/0/ckpts/model.ckpt-1208000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/0/ckpts/model.ckpt-1208000
# Variables being optimized:
# <tf.Variable 'rnn/leaky_rnn_cell/kernel:0' shape=(281, 256) dtype=float32_ref>
# <tf.Variable 'rnn/leaky_rnn_cell/bias:0' shape=(256,) dtype=float32_ref>
# <tf.Variable 'output/weights:0' shape=(256, 3) dtype=float32_ref>
# <tf.Variable 'output/biases:0' shape=(3,) dtype=float32_ref>
# INFO:tensorflow:Restoring parameters from /Users/lauradriscoll/Documents/data/rnn/multitask/crystals/softplus/l2h00001/0/ckpts/model.ckpt-1208000
